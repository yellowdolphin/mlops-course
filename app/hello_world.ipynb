# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
np.random.seed(0)

values = np.random.randn(100)
s = pd.Series(values)
s.plot(kind='hist', title='Gauss', bins=20)
plt.show()
